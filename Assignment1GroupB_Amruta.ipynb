# %%
import pandas as pd

# %%
path="dataset_Facebook (1).csv"

# %%
dt=pd.read_csv(path,sep=';')

# %%
dt
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
dt.iloc[120:,:]
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 120            136393   Photo         1          10             7          9
# 121            136393  Status         2          10             7          9
# 122            136393   Photo         1          10             7          8
# 123            136393   Photo         1          10             7          7
# 124            136393   Photo         1          10             7          6
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
dt.dtypes
# Out:
# Page total likes                                                         int64
# Type                                                                    object
# Category                                                                 int64
# Post Month                                                               int64
# Post Weekday                                                             int64
# Post Hour                                                                int64
# Paid                                                                   float64
# Lifetime Post Total Reach                                                int64
# Lifetime Post Total Impressions                                          int64
# Lifetime Engaged Users                                                   int64
# Lifetime Post Consumers                                                  int64
# Lifetime Post Consumptions                                               int64
# ...

# %%
dt.shape
# Out:
# (500, 19)

# %%
dt.isnull().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   1
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
dt["Paid"] = dt["Paid"].fillna(dt["Paid"].mode()[0])   
dt["like"] = dt["like"].fillna(dt["like"].median())   
dt["share"] = dt["share"].fillna(dt["share"].mean())

# %%
dt.isnull().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   0
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
dt.head(10)
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
# 5            139441  Status         2          12             1          9
# 6            139441   Photo         3          12             1          3
# 7            139441   Photo         3          12             7          9
# 8            139441  Status         2          12             7          3
# 9            139441   Photo         3          12             6         10
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# ...

# %%
s1=dt.loc[dt['Type']=='Status']
s1
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 1              139441  Status         2          12             3         10
# 5              139441  Status         2          12             1          9
# 8              139441  Status         2          12             7          3
# 10             139441  Status         2          12             5         10
# 15             138414  Status         2          12             3         10
# 18             138414  Status         3          12             2          3
# 24             138414  Status         2          12             6         10
# 25             138458  Status         2          12             6          3
# 26             138458  Status         2          12             5         11
# 38             138895  Status         2          12             7          9
# 40             138895  Status         2          12             6         11
# ...

# %%
s2=dt.loc[dt['Type']=='Photo']
s2
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441  Photo         2          12             4          3
# 2              139441  Photo         3          12             3          3
# 3              139441  Photo         2          12             2         10
# 4              139441  Photo         2          12             2          3
# 6              139441  Photo         3          12             1          3
# ..                ...    ...       ...         ...           ...        ...
# 495             85093  Photo         3           1             7          2
# 496             81370  Photo         2           1             5          8
# 497             81370  Photo         1           1             5          2
# 498             81370  Photo         3           1             4         11
# 499             81370  Photo         2           1             4          4
#
# ...

# %%
s3=dt.loc[(dt['Type']=='Photo') & (dt['Category']==3)]
s3
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 2              139441  Photo         3          12             3          3
# 6              139441  Photo         3          12             1          3
# 7              139441  Photo         3          12             7          9
# 9              139441  Photo         3          12             6         10
# 16             138414  Photo         3          12             3          3
# ..                ...    ...       ...         ...           ...        ...
# 491             85979  Photo         3           1             6          3
# 493             85093  Photo         3           1             1          2
# 494             85093  Photo         3           1             7         10
# 495             85093  Photo         3           1             7          2
# 498             81370  Photo         3           1             4         11
#
# ...

# %%
s4=dt[['Type','Category','like','share','Total Interactions']]
s4
# Out:
#        Type  Category    like  share  Total Interactions
# 0     Photo         2    79.0   17.0                 100
# 1    Status         2   130.0   29.0                 164
# 2     Photo         3    66.0   14.0                  80
# 3     Photo         2  1572.0  147.0                1777
# 4     Photo         2   325.0   49.0                 393
# ..      ...       ...     ...    ...                 ...
# 495   Photo         3    53.0   26.0                  84
# 496   Photo         2    53.0   22.0                  75
# 497   Photo         1    93.0   18.0                 115
# 498   Photo         3    91.0   38.0                 136
# 499   Photo         2    91.0   28.0                 119
#
# [500 rows x 5 columns]

# %%
s5=dt[(dt['Type']=='Photo')&(dt['Category']==1)&(dt['Post Weekday']==6)]
s5
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 54             138329  Photo         1          11             6         10
# 68             138185  Photo         1          11             6         11
# 69             137893  Photo         1          11             6          3
# 82             137177  Photo         1          11             6          3
# 96             137059  Photo         1          10             6          3
# 110            136736  Photo         1          10             6         10
# 111            136736  Photo         1          10             6          8
# 127            136393  Photo         1          10             6         13
# 128            136393  Photo         1          10             6         13
# 129            136393  Photo         1          10             6         12
# 130            136393  Photo         1          10             6         11
# ...

# %%
s6=dt.iloc[:,16:20]
s6
# Out:
#        like  share  Total Interactions  rowNumbers
# 0      79.0   17.0                 100           0
# 1     130.0   29.0                 164           1
# 2      66.0   14.0                  80           2
# 3    1572.0  147.0                1777           3
# 4     325.0   49.0                 393           4
# ..      ...    ...                 ...         ...
# 495    53.0   26.0                  84         495
# 496    53.0   22.0                  75         496
# 497    93.0   18.0                 115         497
# 498    91.0   38.0                 136         498
# 499    91.0   28.0                 119         499
#
# [500 rows x 4 columns]

# %%
s7=dt.loc[(dt['Post Hour']>8)&(dt['comment']>1)&(dt['Total Interactions']<100)]
s7
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 42             138353   Photo         1          12             5         10
# 54             138329   Photo         1          11             6         10
# 58             138329   Photo         1          11             4         10
# 64             138185   Photo         1          11             1         10
# 77             137177   Photo         1          11             1         10
# 79             137177   Photo         1          11             7         12
# 102            137020   Photo         3          10             3         10
# 104            137020   Photo         1          10             2         11
# 110            136736   Photo         1          10             6         10
# 145            136013   Photo         1          10             1         10
# 166            135428   Photo         1           9             4         10
# ...

# %%
s8=dt.iloc[1:100,2:10]
s8
# Out:
#     Category  Post Month  Post Weekday  Post Hour  Paid  \
# 1          2          12             3         10   0.0
# 2          3          12             3          3   0.0
# 3          2          12             2         10   1.0
# 4          2          12             2          3   0.0
# 5          2          12             1          9   0.0
# ..       ...         ...           ...        ...   ...
# 95         3          10             6         10   0.0
# 96         1          10             6          3   0.0
# 97         2          10             5         11   0.0
# 98         2          10             5          3   1.0
# 99         1          10             4         10   0.0
#
#     Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 1                       10460                            19057
# 2                        2413                             4373
# 3                       50128                            87991
# ...

# %%
dt1=dt.iloc[:10]
dt2=dt.iloc[10:30]

# %%
merge=pd.concat([dt1,dt2],axis=0)

# %%
merge
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0             139441   Photo         2          12             4          3
# 1             139441  Status         2          12             3         10
# 2             139441   Photo         3          12             3          3
# 3             139441   Photo         2          12             2         10
# 4             139441   Photo         2          12             2          3
# 5             139441  Status         2          12             1          9
# 6             139441   Photo         3          12             1          3
# 7             139441   Photo         3          12             7          9
# 8             139441  Status         2          12             7          3
# 9             139441   Photo         3          12             6         10
# 10            139441  Status         2          12             5         10
# ...

# %%
dt['rowNumbers'] = dt.index
dt3=dt[['Post Month','Post Weekday','Post Hour','rowNumbers']]
dt4=dt[['like','share','comment','rowNumbers']]

merge2=pd.merge(dt3,dt4,on= 'rowNumbers')
merge2
# Out:
#      Post Month  Post Weekday  Post Hour  rowNumbers    like  share  comment
# 0            12             4          3           0    79.0   17.0        4
# 1            12             3         10           1   130.0   29.0        5
# 2            12             3          3           2    66.0   14.0        0
# 3            12             2         10           3  1572.0  147.0       58
# 4            12             2          3           4   325.0   49.0       19
# ..          ...           ...        ...         ...     ...    ...      ...
# 495           1             7          2         495    53.0   26.0        5
# 496           1             5          8         496    53.0   22.0        0
# 497           1             5          2         497    93.0   18.0        4
# 498           1             4         11         498    91.0   38.0        7
# 499           1             4          4         499    91.0   28.0        0
#
# [500 rows x 7 columns]

# %%
dt.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
sort=dt.sort_values(by="Total Interactions",ascending=True)

# %%
sort
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 21             138414  Photo         1          12             7         10
# 441             98195  Photo         1           3             5          4
# 417            104070  Photo         1           3             3         10
# 76             137893  Photo         1          11             3          2
# 100            137020  Photo         1          10             4          9
# ..                ...    ...       ...         ...           ...        ...
# 349            117764  Photo         3           5             5         13
# 460             92507  Photo         3           2             1         13
# 168            135428  Photo         1           9             3         10
# 379            111620  Photo         3           4             1         14
# 244            130791  Photo         2           7             3          5
#
# ...

# %%
sort2=dt.sort_values(by="Total Interactions",ascending=False)

# %%
sort2
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 244            130791  Photo         2           7             3          5
# 379            111620  Photo         3           4             1         14
# 168            135428  Photo         1           9             3         10
# 460             92507  Photo         3           2             1         13
# 349            117764  Photo         3           5             5         13
# ..                ...    ...       ...         ...           ...        ...
# 76             137893  Photo         1          11             3          2
# 100            137020  Photo         1          10             4          9
# 417            104070  Photo         1           3             3         10
# 21             138414  Photo         1          12             7         10
# 441             98195  Photo         1           3             5          4
#
# ...

# %%
sort3=dt.sort_values(by="Post Month",ascending=True)
sort3
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 499             81370   Photo         2           1             4          4
# 498             81370   Photo         3           1             4         11
# 478             86909   Photo         3           1             5         13
# 479             86909   Photo         3           1             5          4
# 476             86909   Photo         1           1             6         10
# ..                ...     ...       ...         ...           ...        ...
# 19             138414   Photo         3          12             1         11
# 18             138414  Status         3          12             2          3
# 1              139441  Status         2          12             3         10
# 0              139441   Photo         2          12             4          3
# 17             138414   Photo         1          12             2         12
#
# ...

# %%
sort4=dt.sort_values(by=["Post Month","Total Interactions","Category"],ascending=True)
sort4
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 481             86491    Link         1           1             4          4
# 485             86491    Link         1           1             2          2
# 487             85979   Photo         3           1             1          2
# 496             81370   Photo         2           1             5          8
# 486             85979   Photo         3           1             1         12
# ..                ...     ...       ...         ...           ...        ...
# 26             138458  Status         2          12             5         11
# 14             138414   Photo         2          12             4          5
# 28             138895   Photo         2          12             5          3
# 17             138414   Photo         1          12             2         12
# 3              139441   Photo         2          12             2         10
#
# ...

# %%
sort5=dt.sort_values(by=["Post Month","Total Interactions","Category"],ascending=False)
sort5
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 3              139441   Photo         2          12             2         10
# 17             138414   Photo         1          12             2         12
# 28             138895   Photo         2          12             5          3
# 14             138414   Photo         2          12             4          5
# 26             138458  Status         2          12             5         11
# ..                ...     ...       ...         ...           ...        ...
# 486             85979   Photo         3           1             1         12
# 496             81370   Photo         2           1             5          8
# 487             85979   Photo         3           1             1          2
# 485             86491    Link         1           1             2          2
# 481             86491    Link         1           1             4          4
#
# ...

# %%
t=dt.transpose()
t
# Out:
#                                                        0       1       2    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %%
dt.shape
# Out:
# (500, 20)

# %%
pivot = dt.pivot_table(index=['Type', 'Category'], values=['Total Interactions', 'like', 'share'], aggfunc='sum')
pivot
# Out:
#                  Total Interactions     like        share
# Type   Category
# Link   1                       1825   1513.0   254.000000
#        2                         49     32.0    15.000000
#        3                         85     68.0    15.000000
# Photo  1                      27526  23285.0  3360.064516
#        2                      25758  21463.0  3231.000000
#        3                      38979  32963.0  4979.000000
# Status 1                        503    409.0    81.000000
#        2                       8534   6937.0  1220.000000
#        3                        730    606.0   113.000000
# Video  1                       2071   1620.0   365.000000

# %%
melt = pivot.melt(var_name='Varname', value_name='Valname', ignore_index=False)
melt
# Out:
#                             Varname       Valname
# Type   Category
# Link   1         Total Interactions   1825.000000
#        2         Total Interactions     49.000000
#        3         Total Interactions     85.000000
# Photo  1         Total Interactions  27526.000000
#        2         Total Interactions  25758.000000
#        3         Total Interactions  38979.000000
# Status 1         Total Interactions    503.000000
#        2         Total Interactions   8534.000000
#        3         Total Interactions    730.000000
# Video  1         Total Interactions   2071.000000
# Link   1                       like   1513.000000
#        2                       like     32.000000
#        3                       like     68.000000
# Photo  1                       like  23285.000000
#        2                       like  21463.000000
#        3                       like  32963.000000
# Status 1                       like    409.000000
# ...

# %%
reshape=pd.melt(dt, id_vars=['Type','Category','Post Month'], value_vars=['like','share','Total Interactions'],var_name='Varname', value_name='Valname')
reshape
# Out:
#         Type  Category  Post Month             Varname  Valname
# 0      Photo         2          12                like     79.0
# 1     Status         2          12                like    130.0
# 2      Photo         3          12                like     66.0
# 3      Photo         2          12                like   1572.0
# 4      Photo         2          12                like    325.0
# ...      ...       ...         ...                 ...      ...
# 1495   Photo         3           1  Total Interactions     84.0
# 1496   Photo         2           1  Total Interactions     75.0
# 1497   Photo         1           1  Total Interactions    115.0
# 1498   Photo         3           1  Total Interactions    136.0
# 1499   Photo         2           1  Total Interactions    119.0
#
# [1500 rows x 5 columns]
