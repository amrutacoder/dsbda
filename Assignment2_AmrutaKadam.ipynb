# %%
import pandas as pd

# %%
path="pima-indians-diabetes.csv"

# %%
dt=pd.read_csv('pima-indians-diabetes (2).csv' , names=['Number of times pregnant' , 'Plasma glucose concentration a 2 hours in an oral glucose tolerance test' , 'Diastolic blood pressure (mm Hg)' , 'Triceps skin fold thickness (mm)' , '2-Hour serum insulin (mu U/ml)' , 'Body mass index (weight in kg/(height in m)^2)' , 'Diabetes pedigree function' , 'Age (years)' , 'Class variable (0 or 1)']	)

# %%
dt=dt.iloc[9: , :]

# %%
dt
# Out:
#     Number of times pregnant  \
# 9                          6
# 10                         1
# 11                         8
# 12                         1
# 13                         0
# ..                       ...
# 772                       10
# 773                        2
# 774                        5
# 775                        1
# 776                        1
#
#      Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 9                                                148.0
# 10                                                85.0
# 11                                               183.0
# 12                                                89.0
# 13                                               137.0
# ..                                                 ...
# 772                                              101.0
# 773                                              122.0
# 774                                              121.0
# ...

# %%
dt=dt.reset_index(drop=True)
dt
# Out:
#     Number of times pregnant  \
# 0                          6
# 1                          1
# 2                          8
# 3                          1
# 4                          0
# ..                       ...
# 763                       10
# 764                        2
# 765                        5
# 766                        1
# 767                        1
#
#      Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                148.0
# 1                                                 85.0
# 2                                                183.0
# 3                                                 89.0
# 4                                                137.0
# ..                                                 ...
# 763                                              101.0
# 764                                              122.0
# 765                                              121.0
# ...

# %%
dt.head()
# Out:
#   Number of times pregnant  \
# 0                        6
# 1                        1
# 2                        8
# 3                        1
# 4                        0
#
#    Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                              148.0
# 1                                               85.0
# 2                                              183.0
# 3                                               89.0
# 4                                              137.0
#
#    Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 0                              72.0                              35.0
# 1                              66.0                              29.0
# 2                              64.0                               0.0
# 3                              66.0                              23.0
# 4                              40.0                              35.0
#
# ...

# %%
dt.isnull().sum()
# Out:
# Number of times pregnant                                                    0
# Plasma glucose concentration a 2 hours in an oral glucose tolerance test    3
# Diastolic blood pressure (mm Hg)                                            1
# Triceps skin fold thickness (mm)                                            1
# 2-Hour serum insulin (mu U/ml)                                              1
# Body mass index (weight in kg/(height in m)^2)                              2
# Diabetes pedigree function                                                  1
# Age (years)                                                                 0
# Class variable (0 or 1)                                                     0
# dtype: int64

# %%
dt=dt.fillna(value=dt.mean(numeric_only=True))
dt.isnull().sum()
# Out:
# Number of times pregnant                                                    0
# Plasma glucose concentration a 2 hours in an oral glucose tolerance test    0
# Diastolic blood pressure (mm Hg)                                            0
# Triceps skin fold thickness (mm)                                            0
# 2-Hour serum insulin (mu U/ml)                                              0
# Body mass index (weight in kg/(height in m)^2)                              0
# Diabetes pedigree function                                                  0
# Age (years)                                                                 0
# Class variable (0 or 1)                                                     0
# dtype: int64

# %%
dt.shape
# Out:
# (768, 9)

# %%
dt.describe()
# Out:
#        Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# count                                         768.000000
# mean                                          120.773856
# std                                            31.830792
# min                                             0.000000
# 25%                                            99.000000
# 50%                                           117.000000
# 75%                                           140.000000
# max                                           199.000000
#
#        Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# count                        768.000000                        768.000000
# mean                          69.114733                         20.518905
# std                           19.354104                         15.944799
# min                            0.000000                          0.000000
# ...

# %%
#data integration
dt1=dt.iloc[:100]
dt2=dt.iloc[100:200]

# %%
merge=pd.concat([dt1,dt2],axis=0)
merge
# Out:
#     Number of times pregnant  \
# 0                          6
# 1                          1
# 2                          8
# 3                          1
# 4                          0
# ..                       ...
# 195                        5
# 196                        1
# 197                        3
# 198                        4
# 199                        4
#
#      Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                148.0
# 1                                                 85.0
# 2                                                183.0
# 3                                                 89.0
# 4                                                137.0
# ..                                                 ...
# 195                                              158.0
# 196                                              105.0
# 197                                              107.0
# ...

# %%
dt.shape
# Out:
# (768, 9)

# %%
import seaborn as sns
sns.heatmap(dt.corr(), annot=True)
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
sns.pairplot(dt, hue='Class variable (0 or 1)')
plt.show()

# %%
plt.figure(figsize=(12, 8))
dt.boxplot(rot=45)
plt.title("Boxplot of Features")
plt.show()

# %%
sns.scatterplot(dt)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=dt, x=dt['Diastolic blood pressure (mm Hg)'], y=dt['2-Hour serum insulin (mu U/ml)'])
plt.xticks(rotation=90)
plt.title("Bar Plot: Blood Pressure vs Serum Insulin")
plt.xlabel("Diastolic Blood Pressure (mm Hg)")
plt.ylabel("Hour Serum Insulin (mu U/ml)")
plt.show()

# %%
from sklearn.model_selection import train_test_split
x = dt.drop(columns=['Class variable (0 or 1)'])
y=dt['Class variable (0 or 1)']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

# %%
y_train
# Out:
# 150    0.0
# 626    0.0
# 129    1.0
# 53     1.0
# 205    0.0
#       ...
# 446    0.0
# 642    1.0
# 215    1.0
# 669    0.0
# 275    0.0
# Name: Class variable (0 or 1), Length: 537, dtype: float64

# %%
x_train
# Out:
#     Number of times pregnant  \
# 150                        1
# 626                        0
# 129                        0
# 53                         8
# 205                        5
# ..                       ...
# 446                        1
# 642                        6
# 215                       12
# 669                        9
# 275                        2
#
#      Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 150                                              136.0
# 626                                              125.0
# 129                                              105.0
# 53                                               176.0
# 205                                              111.0
# ..                                                 ...
# 446                                              100.0
# 642                                              147.0
# 215                                              151.0
# ...

# %%
x_train
# Out:
#     Number of times pregnant  \
# 150                        1
# 626                        0
# 129                        0
# 53                         8
# 205                        5
# ..                       ...
# 446                        1
# 642                        6
# 215                       12
# 669                        9
# 275                        2
#
#      Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 150                                              136.0
# 626                                              125.0
# 129                                              105.0
# 53                                               176.0
# 205                                              111.0
# ..                                                 ...
# 446                                              100.0
# 642                                              147.0
# 215                                              151.0
# ...

# %%
x_test
# Out:
#     Number of times pregnant  \
# 310                        6
# 682                        0
# 429                        1
# 462                        8
# 235                        4
# ..                       ...
# 237                        0
# 41                         7
# 709                        2
# 517                        7
# 569                        0
#
#      Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 310                                               80.0
# 682                                               95.0
# 429                                               95.0
# 462                                               74.0
# 235                                              171.0
# ..                                                 ...
# 237                                              179.0
# 41                                               133.0
# 709                                               93.0
# ...

# %%
y_train
# Out:
# 150    0.0
# 626    0.0
# 129    1.0
# 53     1.0
# 205    0.0
#       ...
# 446    0.0
# 642    1.0
# 215    1.0
# 669    0.0
# 275    0.0
# Name: Class variable (0 or 1), Length: 537, dtype: float64

# %%
y_test
# Out:
# 310    0.0
# 682    0.0
# 429    1.0
# 462    0.0
# 235    1.0
#       ...
# 237    1.0
# 41     0.0
# 709    1.0
# 517    0.0
# 569    1.0
# Name: Class variable (0 or 1), Length: 231, dtype: float64

# %%
from sklearn import svm
from sklearn.metrics import confusion_matrix, classification_report, f1_score,accuracy_score,precision_score,recall_score
model=svm.SVC()

# %%
model.fit(x_train,y_train)
# Out:
# SVC()

# %%
y_pred = model.predict(x_test)

# %%
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[133,   8],
#        [ 56,  34]])

# %%
acc = accuracy_score(y_test, y_pred)
acc
# Out:
# 0.7229437229437229

# %%
print(f"Model Accuracy: {acc* 100:.2f}%")
# Out:
# Model Accuracy: 72.29%

# %%
precision = precision_score(y_test, y_pred)
precision
# Out:
# np.float64(0.8095238095238095)

# %%
recall = recall_score(y_test, y_pred)
recall
# Out:
# np.float64(0.37777777777777777)

# %%
f1 = f1_score(y_test, y_pred)
f1
# Out:
# np.float64(0.5151515151515151)

# %%
user_input = [float(input(f"Enter {col}: ")) for col in x.columns]
prediction = model.predict([user_input])

if prediction[0] == 1:
    print("Diabetic")
else:
    print("Not Diabetic")
# Out:
# Enter Number of times pregnant:  2
